# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cbb_data.csv")

df = df.loc[:, ~df.columns.str.startswith("Unnamed:")]

# %%
df.head
# Out:
# <bound method NDFrame.head of                  BIGDATABALL\nDATASET    GAME-ID       DATE  \
# 0      NCAAB 2024-2025 Regular Season  401706962  11/4/2024
# 1      NCAAB 2024-2025 Regular Season  401706962  11/4/2024
# 2      NCAAB 2024-2025 Regular Season  401719228  11/4/2024
# 3      NCAAB 2024-2025 Regular Season  401719228  11/4/2024
# 4      NCAAB 2024-2025 Regular Season  401706926  11/4/2024
# ...                               ...        ...        ...
# 12583        NCAAB 2025 March Madness  401746080   4/5/2025
# 12584                  NCAAB 2025 NIT  401758636   4/6/2025
# 12585                  NCAAB 2025 NIT  401758636   4/6/2025
# 12586        NCAAB 2025 March Madness  401746082   4/7/2025
# 12587        NCAAB 2025 March Madness  401746082   4/7/2025
#
#                          TEAM    F  OPENING TOTAL  CLOSING SPREAD  \
# 0                Howard Bison   57          152.5            28.5
# 1             Kansas Jayhawks   87          152.5           -28.5
# ...
